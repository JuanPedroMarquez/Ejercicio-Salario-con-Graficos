# %% [markdown]
# # Data Science Salaries 2023

# %% [markdown]
# Este conjunto de datos es útil para entender la distribución de los salarios en el campo de la ciencia de datos y cómo estos pueden variar en función de factores como la ubicación del empleado y del empleador, el nivel de experiencia, el tipo de empleo, entre otros. Nos permite explorar el impacto del trabajo remoto en los salarios de ciencia de datos y empezar a sacar nuestras propias conclusiones.

# %% [markdown]
# #### VARIABLES

# %% [markdown]
# <table>
#   <tr>
#     <th>Nombre de la columna</th>
#     <th>Descripción</th>
#   </tr>
#   <tr>
#     <td>work_year</td>
#     <td>El año en que se pagó el salario.</td>
#   </tr>
#   <tr>
#     <td>experience_level</td>
#     <td>El nivel de experiencia en el trabajo durante el año.</td>
#   </tr>
#   <tr>
#     <td>employment_type</td>
#     <td>El tipo de empleo para el rol.</td>
#   </tr>
#   <tr>
#     <td>job_title</td>
#     <td>El rol desempeñado durante el año.</td>
#   </tr>
#   <tr>
#     <td>salary</td>
#     <td>El total bruto del salario pagado.</td>
#   </tr>
#   <tr>
#     <td>salary_currency</td>
#     <td>La moneda del salario pagado como código de moneda ISO 4217.</td>
#   </tr>
#   <tr>
#     <td>salaryinusd</td>
#     <td>El salario en dólares estadounidenses (USD).</td>
#   </tr>
#   <tr>
#     <td>employee_residence</td>
#     <td>El principal país de residencia del empleado durante el año de trabajo como código de país ISO 3166.</td>
#   </tr>
#   <tr>
#     <td>remote_ratio</td>
#     <td>La cantidad total de trabajo realizado a distancia.</td>
#   </tr>
#   <tr>
#     <td>company_location</td>
#     <td>El país de la oficina principal del empleador o la sucursal contratante.</td>
#   </tr>
#   <tr>
#     <td>company_size</td>
#     <td>El número mediano de personas que trabajaron para la empresa durante el año.</td>
#   </tr>
# </table>

# %% [markdown]
# ### Objetivos:

# %% [markdown]
# El objetivo principal de este ejercicio es aprender y aplicar técnicas de análisis y visualización de datos utilizando las bibliotecas de Python Matplotlib, Seaborn y Plotly.
#
# Los pasos adecuados para completarlo son:
#
# 1. **Explorar el conjunto de datos**: Comprender la estructura del conjunto de datos, los tipos de variables presentes y cómo estas están distribuidas.
#    **Limpiar y preparar el conjunto de datos**: Manipular los datos para que sean más accesibles y útiles para el análisis. Esto puede incluir tratar con valores faltantes, convertir tipos de datos y generar nuevas variables a partir de las existentes.
#
# 2. **Analizar el conjunto de datos**: Extraer información útil y significativa del conjunto de datos a través de diversas técnicas de análisis de datos. </br>
#    **Visualizar los datos**: Crear gráficos y diagramas que ayuden a entender y comunicar los patrones y las relaciones presentes en los datos.
#
# Para responder a las preguntas planteadas se deben usar las siguientes bibliotecas :
#
# - Usar **Matplotlib** para crear gráficos básicos como gráficos de barras, de líneas y de dispersión.
# - Usar **Seaborn** para crear gráficos más complejos y atractivos visualmente, aprovechando sus capacidades de integración con pandas.
# - Usar **Plotly** para crear gráficos interactivos que permiten una exploración más profunda de los datos.

# %% [markdown]
# ### Primer paso, la carga de datos, limpieza, exploración y primera comprensión de nuestro dataset

# %% [markdown]
# #### Importamos las librerías necesarias:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
import plotly.express as px

# %% [markdown]
# #### Cargamos nuestro dataset

# %%
df = pd.read_csv(r"C:\Users\demst\OneDrive\Escritorio\Upgrade_Hub-main\temario\Módulo 1\Plotly\data_practica\ds_salaries.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\demst\OneDrive\Escritorio\Upgrade_Hub-main\temario\Módulo 1\Plotly\data_practica\ds_salaries.csv")
#
# ...

# %%
df.head(15)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0        2023               SE              FT  Principal Data Scientist
# 1        2023               MI              CT               ML Engineer
# 2        2023               MI              CT               ML Engineer
# 3        2023               SE              FT            Data Scientist
# 4        2023               SE              FT            Data Scientist
# 5        2023               SE              FT         Applied Scientist
# 6        2023               SE              FT         Applied Scientist
# 7        2023               SE              FT            Data Scientist
# 8        2023               SE              FT            Data Scientist
# 9        2023               SE              FT            Data Scientist
# 10       2023               SE              FT            Data Scientist
# 11       2023               SE              FT              Data Analyst
# ...

# %% [markdown]
# ¿Cuántas entradas (filas) y variables (columnas) tiene el conjunto de datos?

# %%
df.shape
# Out:
# (3755, 11)

# %% [markdown]
# ¿Qué tipos de datos contiene cada columna?

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# ¿Existen valores faltantes en el conjunto de datos?

# %%
sns.heatmap(df.isnull(), cbar=False, cmap="Blues")
print("Existen un total de: ", df.isnull().sum().sum(), " Valores nulos en nuestro conjunto de datos")
# Out:
# Existen un total de:  0  Valores nulos en nuestro conjunto de datos

# %%
df2= sns.load_dataset('tips')

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# #### ¿Cúal es la distribución que presentan las variables de nuestro dataset?

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
#Sacamos los nombres de las columnas numericas y categoricas
def tipo_de_columnas_ordenadas (df):
    cat = []
    num = []
        
    for col in df.columns:
        if(df[col].dtype == "object"):
            cat.append(col)
        else:
            num.append(col)

    return cat , num

cat , num = tipo_de_columnas_ordenadas(df)
print("Las columnas categoricas son: ", cat)
print("Las columnas numericas son: ", num)
# Out:
# Las columnas categoricas son:  ['experience_level', 'employment_type', 'job_title', 'salary_currency', 'employee_residence', 'company_location', 'company_size']
# Las columnas numericas son:  ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']

# %%
df.describe() # Descripción estadístia de nuestros datos en las columnas numéricas.
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# #### Crea una gráfica para visualizar nuestras variables numéricas:

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(24, 6))
cols = ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']

for i, col in enumerate(cols):
    sns.histplot(data=df, x=col, kde=True, ax=axes[i])
    axes[i].set_title(f'Distribución de {col}')

plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

cols = ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']
fig = make_subplots(rows=1, cols=4)

for i, col in enumerate(cols):
    fig.add_trace(go.Histogram(x=df[col], nbinsx=20, name=f'Distribución de {col}'), row=1, col=i+1, )

fig.update_layout(height=500, width=1200, title_text="Distribución de Variables", showlegend=True)
fig.show()

# %% [markdown]
# #### Crea una gráfica para visualizar nuestras variables categóricas:

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(24, 12))
cols = ['experience_level', 'employment_type', 'job_title', 'salary_currency', 'employee_residence', 'company_size']

for i, column in enumerate(cols):
    row = i // 3
    col = i % 3
    sns.countplot(data=df, x=column, ax=axes[row, col])
    axes[row, col].set_title(f'Distribución de {column}')
    axes[row, col].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

cols = ['experience_level', 'employment_type', 'job_title', 'salary_currency', 'employee_residence', 'company_size', "company_location"]
fig = make_subplots(rows=3, cols=3, subplot_titles=cols)

for i, col in enumerate(cols):
    row = i // 3 + 1
    col = i % 3 + 1
    fig.add_trace(go.Histogram(x=df[cols[i]], nbinsx=20, name=f'Distribución de {cols[i]}'), row=row, col=col)

fig.update_yaxes(showticklabels=False, row=3, col=3)

fig.update_layout(height=400, width=700, title_text="Distribución de Variables", showlegend=False)
fig.update_xaxes(tickangle=90)
fig.show()

# %% [markdown]
# #### Identifica los outliers de nuestro dataset de forma gráfica:

# %%
import math
def identificar_outliers(dataframe):
    """
    Esta función crea un gráfico de caja (boxplot) para cada columna numérica 
    en un DataFrame para ayudar a identificar los outliers.
    """
    # Seleccionamos solo las columnas numéricas
    numeric_cols = dataframe.select_dtypes(include=np.number).columns

    # Creamos los subplots
    ncols = 4
    nrows = math.ceil(len(numeric_cols) / ncols) 
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, 5*nrows))

    # Si el dataframe tiene menos de 4 columnas numéricas, axes no será una lista de listas, por lo que se convierte en una para poder iterar
    if nrows == 1 or ncols == 1:
        axes = [axes]

    for i, col in enumerate(numeric_cols):
        row = i // ncols
        col_idx = i % ncols
        # Comprueba si la columna tiene más de un valor único para evitar errores
        if len(dataframe[col].unique()) > 1:
            sns.boxplot(x=dataframe[col], data=dataframe, ax=axes[row][col_idx])
            axes[row][col_idx].set_title(f"Gráfico: {col}", color="DarkBlue")
        else:
            print(f"La columna {col} tiene un solo valor único y no se puede graficar")

    plt.tight_layout()
    plt.show()

identificar_outliers(df)

# %%
#muestra los outliers con plotly 

for col in num:
    fig = px.box(df, y=col)
    fig.show()

# %% [markdown]
# Mas adelante veremos como tratar el tema de los outliers o profundizar por ejemplo en los valores repetidos y sus posibles causas, en este ejercicio damos por hecho que los valores repetidos no son un error de generación de nuestro dataset y que los outliers encontrados son reales, por lo tanto lejos de eliminarlos, nos sirven para realizar mejores análisis de datos sobre nuestras variables en cuestión.

# %% [markdown]
# ### Segundo paso, la visualización y el análisis de datos de forma gráfica y atractiva:

# %% [markdown]
# Una vez que hemos limpiado y preparado nuestros datos, estamos listos para comenzar a explorarlos y visualizarlos. Si no se nos ha proporcionado un objetivo específico para nuestro análisis, es muy útil formular preguntas sobre nuestros datos. Estas preguntas guiarán nuestras visualizaciones y análisis, y nos ayudarán a descubrir patrones, tendencias e información valiosa.

# %% [markdown]
# #### Preguntas a resolver usando las librerías de creaciones gráficas vistas en clase:

# %% [markdown]
# ¿Cuál es el salario promedio por nivel de experiencia?

# %%
#¿Cuál es el salario promedio por nivel de experiencia?
def strip_plot(dataframe, column1:str, column2:str):
    """
    Función que representa mediante un strip_plot de seaborn, la relación entre dos dimensiones de nuestro conjunto de datos. 
    """
    sns.set(style="whitegrid")
    plt.figure(figsize=(10,6.5))

    graph = sns.stripplot(x=column1, y=column2, data=dataframe, size=5, orient="vertical", jitter=True, palette="rocket")
    graph.set_xticklabels(graph.get_xticklabels(),rotation=90)

    # Mediante ".set" podemos incluir el titulo de nuestro grafico
    graph.set(
        ylabel  = 'Salary (US$)',
        title   = 'Salary by Position Level',
        xlabel  = 'Experience Level'
    )
    plt.show()

strip_plot(df,"experience_level","salary_in_usd")
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\3492116262.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\3492116262.py:10: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df["job_title"].unique().shape
# Out:
# (93,)

# %%
#Vamos a contar las palabras que mas aparecen en job_title
from typing import Counter


df['job_title'] = df['job_title'].str.lower() # Todo en minusculas
df['Split'] = df['job_title'].str.split('-|/|\s+|:') # Dividimos los strings por donde haya una barra o un espacio en blanco
cuenta = Counter()
for i in df['Split']:
    cuenta.update(i)
print(cuenta)
# Out:
# Counter({'data': 2944, 'engineer': 1640, 'scientist': 1065, 'analyst': 684, 'learning': 382, 'machine': 375, 'analytics': 137, 'research': 123, 'science': 116, 'manager': 113, 'architect': 105, 'applied': 82, 'developer': 42, 'bi': 39, 'lead': 38, 'ml': 34, 'of': 31, 'ai': 29, 'computer': 27, 'vision': 27, 'consultant': 26, 'head': 20, 'business': 19, 'specialist': 17, 'infrastructure': 17, 'software': 17, 'principal': 14, 'operations': 14, 'big': 13, 'etl': 12, 'researcher': 11, 'director': 11, 'cloud': 9, 'quality': 7, 'deep': 7, 'nlp': 7, 'product': 6, 'database': 5, 'intelligence': 4, 'mlops': 4, '3d': 4, 'financial': 3, 'marketing': 3, 'modeler': 2, 'strategist': 2, 'staff': 2, 'autonomous': 2, 'vehicle': 2, 'technician': 2, 'programmer': 2, 'insight': 2, 'management': 2, 'compliance': 1, 'devops': 1, 'azure': 1, 'tech': 1, 'power': 1, 'finance': 1})

# %%
# Usando plotly
fig = px.strip(df, x="experience_level", y="salary_in_usd", template="plotly_dark", color='job_title', title="Salario según nivel de experiencia", )
fig.update_xaxes(tickangle=90)
fig.show()

# %%
px.scatter_matrix(df, dimensions=['salary_in_usd', 'remote_ratio'], color="job_title", title="Matriz de dispersión con plotly express", template="plotly_dark")

# %%
px.scatter_3d(df, x='salary_in_usd', y='remote_ratio', z='salary', color='job_title', title="Matriz espacial de dispersión en plotly", template="plotly_dark")

# %%
px.sunburst(df, path=['job_title','salary_in_usd'], values='salary_in_usd', color='company_location',  title="Salario por ubicaciones", template="plotly_dark")

# %% [markdown]
# ¿Cómo ha cambiado el salario medio con el paso del tiempo (work_year)?

# %%
#¿Cómo ha cambiado el salario medio con el paso del tiempo (work_year)?

# Primero tenemos qu calcular el salario medio por año
average_salary_per_year = df.groupby('work_year')['salary_in_usd'].mean().reset_index()

fig = px.line(average_salary_per_year, x='work_year', y='salary_in_usd', 
              title='Evolución del salario medio con el paso del tiempo', template="plotly_dark", color_discrete_sequence=['yellow'])

fig.show()

# %%
average_salary_per_year = df.groupby('work_year')['salary_in_usd'].agg(['mean', 'std']).reset_index()

fig = px.area(average_salary_per_year, x='work_year', y='mean', 
              title='Evolución del salario medio con el paso del tiempo', template="plotly_dark", color_discrete_sequence=['yellow'])

fig.add_candlestick(x=average_salary_per_year['work_year'],
                    open=average_salary_per_year['mean'],
                    close=average_salary_per_year['mean'],
                    high=average_salary_per_year['mean'] + average_salary_per_year['std'],
                    low=average_salary_per_year['mean'] - average_salary_per_year['std'],
                    increasing_line_color='blue',
                    decreasing_line_color='red'
                    )


fig.show()

# %%
#sacamos de jobtite las concidencias de Data Scientist
df_2 = df.copy()
df_2 = df_2[df_2['job_title'].str.contains('Data Scientist')]
df_2.head() #solo contiene data cientist
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size, Split]
# Index: []

# %%
#Con seaborn
plt.figure(figsize=(12,8))
salary_order = sns.lineplot(x=df['work_year'], y=df['salary_in_usd'],  color="red")
salary_order.set_xlabel('años de experiencía')
salary_order.set_ylabel('Salary USD ($)')
plt.show()

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  principal data scientist
# 1          2023               MI              CT               ml engineer
# 2          2023               MI              CT               ml engineer
# 3          2023               SE              FT            data scientist
# 4          2023               SE              FT            data scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            data scientist
# 3751       2021               MI              FT  principal data scientist
# 3752       2020               EN              FT            data scientist
# 3753       2020               EN              CT     business data analyst
# 3754       2021               SE              FT      data science manager
#
# ...

# %%
ds = df.query('job_title == "data scientist"').groupby('work_year')['salary_in_usd'].mean().round(2)
print(ds)
# Out:
# work_year
# 2020     85970.52
# 2021     73351.43
# 2022    136487.10
# 2023    156812.12
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# ¿Cuál es la proporción de trabajo remoto entre diferentes roles de trabajo?

# %%
# Calculamos la proporción media de trabajo remoto para cada puesto de trabajo
average_remote_ratio_per_job = df.groupby('job_title')['remote_ratio'].mean().reset_index()

fig = px.bar(average_remote_ratio_per_job, y='job_title', x='remote_ratio', 
             title='Proporción media de trabajo remoto por tipo de trabajo', template="plotly_dark", color_discrete_sequence=['red'], height=1200, orientation='h')

fig.show()

# %%
# Ordenar el DataFrame por la proporción media de trabajo remoto
average_remote_ratio_per_job = average_remote_ratio_per_job.sort_values('remote_ratio')

sns.set_theme(style='darkgrid')

plt.figure(figsize=(18, 14))
sns.barplot(data=average_remote_ratio_per_job, y='job_title', x='remote_ratio', palette='rocket')
plt.title('Proporción media de trabajo remoto por tipo de trabajo')
plt.xlabel('Proporción media de trabajo remoto')
plt.ylabel('Tipo de trabajo')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\3933251387.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ¿Existe una relación entre el tamaño de la empresa y el salario?

# %%
fig = px.box(df, x='company_size', y='salary_in_usd', 
             title='Relación entre el tamaño de la empresa y el salario', 
             category_orders={"company_size": ["S", "M", "L"]}, # Damos nosotros el orden de las variables (Pequeña,Mediana,Grande)
             template="plotly_dark", color='company_size') # añadimos color para diferenciar mejor los tamaños de empresa

fig.show()

# %%
#Con seaborn
plt.figure(figsize=(8,8))
sns.boxplot(x='company_size', y='salary_in_usd', data=df, palette = "rocket")
plt.title('Tamaño empresa por salario salario  ')
plt.xlabel('Tamaño empresa')
plt.ylabel('Salario')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\1656080297.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Convertimos el tamaño de la empresa a números: "S"->1, "M"->2, "L"->3
df['company_size_num'] = df['company_size'].map({'S': 1, 'M': 2, 'L': 3})

# Calculamos la matriz de correlación
corr = df[['salary_in_usd', 'company_size_num']].corr()

# Creamos un mapa de calor 
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Correlación entre el salario y el tamaño de la empresa')
plt.show()

# %% [markdown]
# ¿Cuál es el país con más trabajadores remotos?

# %%
remote_work_by_country = df.groupby('employee_residence')['remote_ratio'].sum().reset_index()

fig = px.bar(remote_work_by_country.sort_values('remote_ratio', ascending=False), x='employee_residence', y='remote_ratio', 
             title='Cantidad de trabajadores remotos por país', template="plotly_dark")
fig.update_xaxes(tickangle=90)

fig.show()

# %%
# Con seaborn
remote_work_by_country = df.groupby('employee_residence')['remote_ratio'].sum().reset_index()

sns.set_theme(style='darkgrid')

plt.figure(figsize=(15, 8))
sns.barplot(data=remote_work_by_country, x='employee_residence', y='remote_ratio', palette='Blues')
plt.title('Cantidad de trabajadores remotos por país')
#giramos los nombres
plt.xticks(rotation=90)
plt.xlabel('País')
plt.ylabel('Cantidad de trabajadores remotos')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\416029838.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ¿Cómo ha cambiado la proporción de trabajo remoto con el paso del tiempo?

# %%
remote_work_per_year = df.groupby('work_year')['remote_ratio'].mean().reset_index()

fig = px.line(remote_work_per_year, x='work_year', y='remote_ratio', title='Proporción de empleados remotos con el paso del tiempo',
                template="plotly_dark", color_discrete_sequence=['green'])

fig.show()

# %%
#Con seaborn
plt.figure(figsize=(12,8))
sns.lineplot(x='work_year',y='remote_ratio',data=df,color='green').set_title('Proporción de empleados remotos con el paso del tiempo')
plt.ylabel('Proporción de empleados remotos')
plt.xlabel('tiempo de experiencia')
plt.show()

# %% [markdown]
# ¿Cuál es el país con los salarios promedio más altos en USD?

# %%
#¿Cuál es el país con los salarios promedio más altos en USD?
avg_salary_by_country = df.groupby('employee_residence')['salary_in_usd'].mean().reset_index()

fig = px.bar(avg_salary_by_country.sort_values('salary_in_usd', ascending=False),
                x='employee_residence', y='salary_in_usd', title='Países con los salarios más altos en USD',
                template="plotly_dark", color_discrete_sequence=['#2ad9e5'])

fig.show()

# %%
# Con seaborn
avg_salary_by_country = df.groupby('employee_residence')['salary_in_usd'].mean().reset_index()
plt.figure(figsize=(16,8))
order = df.groupby('employee_residence')['salary_in_usd'].mean().sort_values(ascending=False).index.values

sns.barplot(data = df,
            x='employee_residence',
            y='salary_in_usd',
            order=order,
              ).set_title('Países más salarios más altos en USD por país')
plt.xticks(rotation=90)
plt.ylabel('Salario')
plt.xlabel('País')
plt.show()

# %% [markdown]
# ¿Cómo se distribuyen los roles de trabajo en las diferentes categorías de experiencia?

# %%
experience_job_ds = df.groupby(['experience_level', 'job_title']).size().reset_index(name='Count') 

fig = px.treemap(experience_job_ds, path=['experience_level', 'job_title'], values='Count', title="Evolución del salario medio con el paso del tiempo, seasjdkalsd jasdkasdjas aksdlajsdlkdj", template="plotly_dark")

fig.show()

# %% [markdown]
# ¿Cómo varía el salario promedio entre los diferentes tipos de empleo, fulltime, partime ect?

# %%
avg_salary_by_employment = df.groupby('employment_type')['salary_in_usd'].mean().reset_index()

fig = px.bar(avg_salary_by_employment.sort_values('salary_in_usd', ascending=False),
                x='employment_type', y='salary_in_usd', title='Salario medio por tipo de empleo',
                template="plotly_dark", color_discrete_sequence=['cyan'])

fig.show()

# %%
avg_salary_by_employment = df.groupby('employment_type')['salary_in_usd'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.set_theme(style='darkgrid')

sns.barplot(data=avg_salary_by_employment.sort_values('salary_in_usd', ascending=False), 
            x='employment_type', y='salary_in_usd', palette='cool', edgecolor='black')

plt.title('Salario medio por tipo de empleo')
plt.xlabel('Tipo de empleo')
plt.ylabel('Salario medio (USD)')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\2019107602.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# #### Crear un top10 con los empleos mas demandados:

# %%
top10_empleos = df.job_title.value_counts()[:10].index.tolist()
fig = px.pie(df[df.job_title.isin(top10_empleos)], 'job_title', height=600 , title='Top 10 de empleos en esta encuesta', template="plotly_dark")

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
top10_empleos = df.job_title.value_counts()[:10].index.tolist()

plt.figure(figsize=(8, 8))
sns.set_theme(style='darkgrid')

sns.countplot(data=df[df.job_title.isin(top10_empleos)], y='job_title', palette='Set3')

plt.title('Top 10 de empleos en Data')
plt.xlabel('Cantidad de empleados')
plt.ylabel('Título del empleo')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\1549116175.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ####  Crear un top10 con los empleos mas cotizados:

# %%
top10_cotizados = df.groupby('job_title')['salary_in_usd'].mean().reset_index() 
top10_cotizados.sort_values(by='salary_in_usd', inplace=True, ascending=False)

fig = px.bar(top10_cotizados[:10], y='job_title', x='salary_in_usd', color='job_title', title='Top 10 empleos más cotizados', template="plotly_dark")
fig.show()

# %%
top10_cotizados = df.groupby('job_title')['salary_in_usd'].mean().reset_index()
top10_cotizados = top10_cotizados.sort_values(by='salary_in_usd', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.set_theme(style='darkgrid')

sns.barplot(data=top10_cotizados, y='job_title', x='salary_in_usd', palette='Set3')

plt.title('Top 10 empleos más cotizados')
plt.xlabel('Salario medio (USD)')
plt.ylabel('Título del empleo')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\415582577.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ####  Crear un top10 con empleos donde podemos trabajar remoto:

# %%
top10_remotos = df.groupby('job_title')['remote_ratio'].mean().reset_index()
fig = px.funnel(top10_remotos[:10].sort_values(by='remote_ratio', ascending=False), x='job_title', y='remote_ratio', 
                title='Top 10 de profesiones que más trabajo remoto tienen', color_discrete_sequence=['#4b8cff'], template="plotly_dark")
fig.show()

# %%
#Con seaborn
top10_remotos = df.groupby('job_title')['remote_ratio'].mean().reset_index()
top10_remotos = top10_remotos.sort_values(by='remote_ratio', ascending=False).head(10)

plt.figure(figsize=(8, 6))
sns.set_theme(style='darkgrid')

sns.barplot(data=top10_remotos, y='job_title', x='remote_ratio', palette=['#4b8cff'])

plt.title('Top 10 de profesiones que más trabajo remoto tienen')
plt.xlabel('Proporción de trabajo remoto')
plt.ylabel('Título del empleo')

plt.show()
# Out:
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\2860712529.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\demst\AppData\Local\Temp\ipykernel_7972\2860712529.py:8: UserWarning:
#
#
# The palette list has fewer values (1) than needed (10) and will cycle, which may produce an uninterpretable plot.

# %% [markdown]
# ## USando la nueva librería PandasAI

# %%
from pandasai import PandasAI
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 from pandasai import PandasAI
#       2 import pandas as pd
#
# ImportError: cannot import name 'PandasAI' from 'pandasai' (C:\Users\demst\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandasai\__init__.py)

# %%
data = pd.read_csv('/home/deme/Documents/GitHub/Upgrade_Hub/temario/Módulo 1/Plotly/data_practica/ds_salaries.csv')

# %%
#Iniciamos el modelo de procesamiento de lenguaje
from pandasai.llm.openai import OpenAI
llm= OpenAI(api_token='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')

# %%
pandas_ai = PandasAI(llm) #unumos nuesta clave api con el procesador

# %%
pandas_ai(data, prompt="Cuales son los paises donde se trabaja mas remoto")
# Out:
# ['RS', 'CF', 'KE', 'LU', 'MY']

# %%
pandas_ai(data, prompt="un gráfico de barras con el top10 empleos mas demandados")

# %%
pandas_ai(data, prompt="Cual sería el promedio de los salarios mas demandados, grafica el top10 de forma clara donde la x sea el empleo y la y el salario")

# %%
pandas_ai(data, prompt="Creame una columna nueva llamada especialización en la que me indique un grupo determinado de la rama de data, vamos a agrupar toda nuestra columna job_title en cinco ramas, ingenieria de datos, analisis de datos, data cientist, business analisis y inteligencia artificial")
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size           specialization
# ...

# %%
data["specialization"].value_counts()
# Out:
# specialization
# Data Engineering           1051
#                             921
# Data Scientist              848
# Data Analysis               612
# Artificial Intelligence     323
# Name: count, dtype: int64

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  principal data scientist
# 1          2023               MI              CT               ml engineer
# 2          2023               MI              CT               ml engineer
# 3          2023               SE              FT            data scientist
# 4          2023               SE              FT            data scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            data scientist
# 3751       2021               MI              FT  principal data scientist
# 3752       2020               EN              FT            data scientist
# 3753       2020               EN              CT     business data analyst
# 3754       2021               SE              FT      data science manager
#
# ...
